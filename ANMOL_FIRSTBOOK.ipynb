# %%
import pandas as pd
df=pd.read_csv("annual_csv.csv")
df
#we can check the arguments a function takes by using shift +tab
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.shape  #decribe no. of rows and coloumns
# Out:
# (32445, 10)

# %%
df.head() #print few starting rows
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
# 2  2019                     Level 1                99999       All industries
# 3  2019                     Level 1                99999       All industries
# 4  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.head(2) #print top two rows
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  728,239  ANZSIC06 divisions A-S (excluding classes K633...
# 1  643,809  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df.tail(1) #print the last row
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32444  Food product manufacturing  Percentage           H41
#
#                Variable_name Variable_category Value  \
# 32444  Liabilities structure  Financial ratios    46
#
#                                   Industry_code_ANZSIC06
# 32444  ANZSIC06 groups C111, C112, C113, C114, C115, ...

# %%
df[2:5]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 2  2019                     Level 1                99999       All industries
# 3  2019                     Level 1                99999       All industries
# 4  2019                     Level 1                99999       All industries
#
#                 Units Variable_code                      Variable_name  \
# 2  Dollars (millions)           H05  Interest, dividends and donations
# 3  Dollars (millions)           H07               Non-operating income
# 4  Dollars (millions)           H08                  Total expenditure
#
#        Variable_category    Value  \
# 2  Financial performance   62,924
# 3  Financial performance   21,505
# 4  Financial performance  634,710
#
#                               Industry_code_ANZSIC06
# 2  ANZSIC06 divisions A-S (excluding classes K633...
# 3  ANZSIC06 divisions A-S (excluding classes K633...
# 4  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df.Year #print the Year
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 32440    2013
# 32441    2013
# 32442    2013
# 32443    2013
# 32444    2013
# Name: Year, Length: 32445, dtype: int64

# %%
df['Units']  # second way to print perticular thing
# Out:
# 0        Dollars (millions)
# 1        Dollars (millions)
# 2        Dollars (millions)
# 3        Dollars (millions)
# 4        Dollars (millions)
#                 ...
# 32440            Percentage
# 32441            Percentage
# 32442            Percentage
# 32443            Percentage
# 32444            Percentage
# Name: Units, Length: 32445, dtype: object

# %%
type(df['Year'])
# Out:
# pandas.core.series.Series

# %%
df[['Value','Variable_name','Units']] #print more than one column
# Out:
#          Value                                    Variable_name  \
# 0      728,239                                     Total income
# 1      643,809  Sales, government funding, grants and subsidies
# 2       62,924                Interest, dividends and donations
# 3       21,505                             Non-operating income
# 4      634,710                                Total expenditure
# ...        ...                                              ...
# 32440       52                                      Quick ratio
# 32441       40              Margin on sales of goods for resale
# 32442       12                                 Return on equity
# 32443        5                           Return on total assets
# 32444       46                            Liabilities structure
#
#                     Units
# 0      Dollars (millions)
# 1      Dollars (millions)
# 2      Dollars (millions)
# 3      Dollars (millions)
# 4      Dollars (millions)
# ...                   ...
# ...

# %%
df['Units'].max()
# Out:
# 'Percentage'

# %%
df['Value'].max()  #prints the max value in value column
# Out:
# 'S'

# %%
df.fillna(0, inplace=True) #it fills the empty positions in our sheet with 0 value known as data muggling.

# %%
df.describe()   #prints stats of our df
# Out:
#                Year
# count  32445.000000
# mean    2016.000000
# std        2.000031
# min     2013.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2019.000000

# %%
df[df.Value==df.Value.max()] #prints all data whose value is max
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 3537   2019                     Level 4                LL122
# 3538   2019                     Level 4                LL122
# 8172   2018                     Level 4                LL122
# 8173   2018                     Level 4                LL122
# 12807  2017                     Level 4                LL122
# 12808  2017                     Level 4                LL122
# 17442  2016                     Level 4                LL122
# 17443  2016                     Level 4                LL122
# 21645  2015                     Level 1                   KK
# 21647  2015                     Level 1                   KK
# 21679  2015                     Level 3                 KK11
# 21681  2015                     Level 3                 KK11
# 21747  2015                     Level 4                KK112
# 21749  2015                     Level 4                KK112
# ...

# %%
df['Year'][df.Value==df.Value.max()]  #prints all the year where value is max
# Out:
# 3537     2019
# 3538     2019
# 8172     2018
# 8173     2018
# 12807    2017
# 12808    2017
# 17442    2016
# 17443    2016
# 21645    2015
# 21647    2015
# 21679    2015
# 21681    2015
# 21747    2015
# 21749    2015
# 22077    2015
# 22078    2015
# 31347    2013
# 31348    2013
# Name: Year, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32445, step=1)

# %%
df.set_index('Year', inplace=True) #we have set the index from numbering to year

# %%
df   #inplace=true is to modify our database
# Out:
#      Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 2019                     Level 1                99999
# 2019                     Level 1                99999
# 2019                     Level 1                99999
# 2019                     Level 1                99999
# 2019                     Level 1                99999
# ...                          ...                  ...
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 2019              All industries  Dollars (millions)           H01
# 2019              All industries  Dollars (millions)           H04
# 2019              All industries  Dollars (millions)           H05
# ...

# %%
df.loc[2019] #loc helps to print perticular data from our index here we choose only 2019
# Out:
#      Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 2019                     Level 1                99999
# 2019                     Level 1                99999
# 2019                     Level 1                99999
# 2019                     Level 1                99999
# 2019                     Level 1                99999
# ...                          ...                  ...
# 2019                     Level 3                 ZZ11
# 2019                     Level 3                 ZZ11
# 2019                     Level 3                 ZZ11
# 2019                     Level 3                 ZZ11
# 2019                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 2019              All industries  Dollars (millions)           H01
# 2019              All industries  Dollars (millions)           H04
# 2019              All industries  Dollars (millions)           H05
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#        index  Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0          0  2019                     Level 1                99999
# 1          1  2019                     Level 1                99999
# 2          2  2019                     Level 1                99999
# 3          3  2019                     Level 1                99999
# 4          4  2019                     Level 1                99999
# ...      ...   ...                         ...                  ...
# 32440  32440  2013                     Level 3                 ZZ11
# 32441  32441  2013                     Level 3                 ZZ11
# 32442  32442  2013                     Level 3                 ZZ11
# 32443  32443  2013                     Level 3                 ZZ11
# 32444  32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# ...
